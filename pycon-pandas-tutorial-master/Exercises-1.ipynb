# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1        Ashes of Kukulcan  2016
# 2  The Thousand Plane Raid  1969
# 3         Crucea de piatra  1993
# 4                   The 86  2015

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                                title  year       name   type character   n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
titles.shape[0]
# Out:
# 217015

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort(columns='year')[0:2]
# Out:
#                                                     title  year
# 165976                                         Miss Jerry  1894
# 86144   Reproduction of the Corbett and Fitzsimmons Fight  1897

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
titles[titles['title']=='Hamlet'].shape[0]
# Out:
# 19

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
titles[titles['title']=='North by Northwest'].shape[0]
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles['title']=='Hamlet'].sort(columns='year')['year'].values[0]
# Out:
# 1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles['title']=='Treasure Island'].sort(columns='year')
# Out:
#                   title  year
# 192297  Treasure Island  1918
# 47976   Treasure Island  1920
# 193841  Treasure Island  1934
# 90629   Treasure Island  1950
# 214069  Treasure Island  1972
# 104141  Treasure Island  1973
# 191705  Treasure Island  1985
# 167480  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
titles[titles['year']==1950].shape[0]
# Out:
# 1037

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
titles[titles['year']==1960].shape[0]
# Out:
# 1465

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
titles[(titles['year']>1950)&(titles['year']<1960)].shape[0]
# Out:
# 11089

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
print(titles[titles['title']=="Batman"]['year'].values)
# Out:
# [1989 1943]

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast[(cast['title']=="Inception")&(cast['year']==2010)].shape[0]
# Out:
# 74

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
sum(cast[(cast['title']=="Inception")&(cast['year']==2010)]['n'].isnull())
# Out:
# 23

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
sum(cast[(cast['title']=="Inception")&(cast['year']==2010)]['n'].notnull())
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[cast['title']=='North by Northwest'].dropna().sort(columns='n')
# Out:
#                       title  year                  name     type  \
# 782818   North by Northwest  1959            Cary Grant    actor
# 3124456  North by Northwest  1959       Eva Marie Saint  actress
# 1308420  North by Northwest  1959           James Mason    actor
# 2811840  North by Northwest  1959   Jessie Royce Landis  actress
# 319325   North by Northwest  1959        Leo G. Carroll    actor
# 2719225  North by Northwest  1959  Josephine Hutchinson  actress
# 1523102  North by Northwest  1959           Philip Ober    actor
# 1144419  North by Northwest  1959         Martin Landau    actor
# 2194916  North by Northwest  1959         Adam Williams    actor
# 1626637  North by Northwest  1959          Edward Platt    actor
# 597922   North by Northwest  1959     Robert Ellenstein    actor
# 2059013  North by Northwest  1959          Les Tremayne    actor
# 416353   North by Northwest  1959       Philip Coolidge    actor
# 1355247  North by Northwest  1959         Patrick McVey    actor
# 183303   North by Northwest  1959          Edward Binns    actor
# 1243228  North by Northwest  1959             Ken Lynch    actor
#
#                            character   n
# 782818            Roger O. Thornhill   1
# 3124456                  Eve Kendall   2
# 1308420              Phillip Vandamm   3
# 2811840              Clara Thornhill   4
# 319325                 The Professor   5
# 2719225                Mrs. Townsend   6
# 1523102              Lester Townsend   7
# 1144419                      Leonard   8
# 2194916                     Valerian   9
# 1626637              Victor Larrabee  10
# 597922                         Licht  11
# 2059013                   Auctioneer  12
# 416353                     Dr. Cross  13
# 1355247               Sergeant Flamm  14
# 183303                Captain Junket  15
# 1243228  Charley - Chicago Policeman  16

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast['title']=='Sleuth')&(cast['year']==1972)].sort(columns='n')
# Out:
#           title  year                name     type  \
# 1532035  Sleuth  1972    Laurence Olivier    actor
# 292201   Sleuth  1972       Michael Caine    actor
# 334890   Sleuth  1972      Alec Cawthorne    actor
# 1315790  Sleuth  1972  John (II) Matthews    actor
# 2437135  Sleuth  1972  Eve (III) Channing  actress
# 1300932  Sleuth  1972        Teddy Martin    actor
#
#                           character  n
# 1532035                 Andrew Wyke  1
# 292201                  Milo Tindle  2
# 334890            Inspector Doppler  3
# 1315790  Detective Sergeant Tarrant  4
# 2437135             Marguerite Wyke  5
# 1300932      Police Constable Higgs  6

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast['title']=='Sleuth')&(cast['year']==2007)].sort(columns='n')
# Out:
#           title  year                 name     type          character   n
# 292202   Sleuth  2007        Michael Caine    actor             Andrew   1
# 1161113  Sleuth  2007             Jude Law    actor               Milo   2
# 1621807  Sleuth  2007        Harold Pinter    actor        Man on T.V.   3
# 231722   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V. NaN
# 334891   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler NaN
# 2437134  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke NaN
# 2996818  Sleuth  2007    Carmel O'Sullivan  actress             Maggie NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast['title']=='Hamlet')&(cast['year']==1921)].shape[0]
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[(cast['title']=='Hamlet')&(cast['year']==1996)].shape[0]
# Out:
# 55

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[(cast['character']=='Hamlet')].shape[0]
# Out:
# 82

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[(cast['character']=='Ophelia')]['name'].unique().shape[0]
# Out:
# 95

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[(cast['character']=='The Dude')]['name'].unique().shape[0]
# Out:
# 16

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[(cast['character']=='The Stranger')]['name'].unique().shape[0]
# Out:
# 184

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[(cast['name']=='Sidney Poitier')]['character'].unique().shape[0]
# Out:
# 41

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[(cast['name']=='Judi Dench')]['character'].unique().shape[0]
# Out:
# 44

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast['name']=='Cary Grant')&(cast['n']==2)&(cast['year']>=1940)&(cast['year']<1950)].sort(columns='year')
# Out:
#                    title  year        name   type    character  n
# 782815  My Favorite Wife  1940  Cary Grant  actor         Nick  2
# 782825    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast['name']=='Cary Grant')&(cast['n']==1)&(cast['year']>=1940)&(cast['year']<1950)].sort(columns='year')
# Out:
#                                        title  year        name   type  \
# 782840               The Howards of Virginia  1940  Cary Grant  actor
# 782797                       His Girl Friday  1940  Cary Grant  actor
# 782842                The Philadelphia Story  1940  Cary Grant  actor
# 782830                             Suspicion  1941  Cary Grant  actor
# 782844                  The Talk of the Town  1942  Cary Grant  actor
# 782821                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 782788                     Destination Tokyo  1943  Cary Grant  actor
# 782813                             Mr. Lucky  1943  Cary Grant  actor
# 782814                             Mr. Lucky  1943  Cary Grant  actor
# 782822                      Once Upon a Time  1944  Cary Grant  actor
# 782780                  Arsenic and Old Lace  1944  Cary Grant  actor
# 782817             None But the Lonely Heart  1944  Cary Grant  actor
# 782816                         Night and Day  1946  Cary Grant  actor
# 782819                             Notorious  1946  Cary Grant  actor
# 782836      The Bachelor and the Bobby-Soxer  1947  Cary Grant  actor
# 782837                     The Bishop's Wife  1947  Cary Grant  actor
# 782812  Mr. Blandings Builds His Dream House  1948  Cary Grant  actor
# 782792          Every Girl Should Be Married  1948  Cary Grant  actor
# 782801                I Was a Male War Bride  1949  Cary Grant  actor
#
#                     character  n
# 782840            Matt Howard  1
# 782797           Walter Burns  1
# 782842     C. K. Dexter Haven  1
# 782830                Johnnie  1
# 782844           Leopold Dilg  1
# 782821  Patrick 'Pat' O'Toole  1
# 782788          Capt. Cassidy  1
# 782813              Joe Adams  1
# 782814        Joe Bascopolous  1
# 782822            Jerry Flynn  1
# 782780      Mortimer Brewster  1
# 782817             Ernie Mott  1
# 782816            Cole Porter  1
# 782819                 Devlin  1
# 782836            Dick Nugent  1
# 782837                 Dudley  1
# 782812          Jim Blandings  1
# 782792      Dr. Madison Brown  1
# 782801    Capt. Henri Rochard  1

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[(cast['type']=='actor')&(cast['year']>=1940)&(cast['year']<1950)].shape[0]
# Out:
# 157522

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
cast[(cast['type']=='actress')&(cast['year']>=1940)&(cast['year']<1950)].shape[0]
# Out:
# 49951

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast['n']==1)&(cast['year']<=1980)].shape[0]
# Out:
# 61746

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast[(cast['n']!=1)&(cast['year']<=1980)].shape[0]
# Out:
# 1056174

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
sum(cast[(cast['year']<=1980)]['n'].isnull())
# Out:
# 419834
